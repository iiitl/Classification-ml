# %%
import pandas as pd

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
x=df.drop(columns=['Species'])
y=df['Species']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.svm import SVC

# %% [markdown]
# BEFORE GRIDSEARCHCV

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=200),
    "Random Forest": RandomForestClassifier(),
    "SVC" : SVC()
}

# %%
def evaluate(model,x_train,y_train,x_test,y_test):
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    accuracy=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred,average='weighted')
    recall=recall_score(y_test,y_pred,average='weighted')
    f1=f1_score(y_test,y_pred,average='weighted')

    return accuracy,precision,recall,f1

# %%
ans={}
for name,model in models.items():
    accuracy,precision,recall,f1=evaluate(model,x_train,y_train,x_test,y_test)
    ans[name]={'accuracy':accuracy,'precision':precision,'recall':recall,'f1':f1}
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
for key,value in ans.items():
    print(key+ ":" )
    print(value)
# Out:
# Logistic Regression:
# {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}
# Random Forest:
# {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}
# SVC:
# {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}

# %% [markdown]
# AFTER GRIDSEARCHCV

# %%
param_grids = {
    "Logistic Regression": {
        "C": [0.01, 0.1, 1, 10, 100],
        "max_iter": [200, 300, 400]
    },
    "Random Forest": {
        "n_estimators": [50, 100, 200],
        "max_depth": [None, 10, 20],
        "min_samples_split": [2, 5, 10]
    },
    "SVC": {
        "C": [0.1, 1, 10],
        "kernel": ['linear', 'rbf', 'poly']
    }
}

# %%
def grid_search_cv(model, param_grid, X_train, y_train):
    search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
    search.fit(X_train, y_train)

    best_model = search.best_estimator_
    best_params = search.best_params_

    return best_model, best_params

# %%
ansgscv = {}

# %%
def evaluate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    return accuracy, precision, recall, f1

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
for name, model in models.items():

    best_model, best_params = grid_search_cv(model, param_grids[name], x_train, y_train)

    accuracy, precision, recall, f1 = evaluate(best_model, x_train, y_train, x_test, y_test)

    ansgscv[name] = {
        'best_params': best_params,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,

    }
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
for name,value in ansgscv.items():
    print(name+ ":")
    print(value)
# Out:
# Logistic Regression:
# {'best_params': {'C': 1, 'max_iter': 300}, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}
# Random Forest:
# {'best_params': {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200}, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}
# SVC:
# {'best_params': {'C': 0.1, 'kernel': 'linear'}, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}
