# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Dataset

# %%
data = pd.read_csv('cleaned-in-vehicle-coupon-recommendation.csv')
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       1~3                  4~8              1~3
# ...

# %%
print(data.shape)
data.info()
# Out:
# (12610, 25)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12610 entries, 0 to 12609
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12610 non-null  object
#  1   passanger             12610 non-null  object
#  2   weather               12610 non-null  object
#  3   temperature           12610 non-null  int64
#  4   time                  12610 non-null  object
#  5   coupon                12610 non-null  object
#  6   expiration            12610 non-null  object
#  7   gender                12610 non-null  object
#  8   age                   12610 non-null  object
#  9   maritalStatus         12610 non-null  object
#  10  has_children          12610 non-null  int64
#  11  education             12610 non-null  object
#  12  occupation            12610 non-null  object
#  13  income                12610 non-null  object
# ...

# %%
cols = ['temperature', 'has_children', 'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min' ,'direction_same' , 'direction_opp']

for col in cols:
    print(f"Unique values in {col}: {data[col].unique()}")
# Out:
# Unique values in temperature: [55 80 30]
# Unique values in has_children: [1 0]
# Unique values in toCoupon_GEQ5min: [1]
# Unique values in toCoupon_GEQ15min: [0 1]
# Unique values in toCoupon_GEQ25min: [0 1]
# Unique values in direction_same: [0 1]
# Unique values in direction_opp: [1 0]

# %% [markdown]
# ## Visualize outliers

# %% [markdown]
# ### Box Plots

# %%
cols = ['temperature', 'has_children', 'toCoupon_GEQ5min', 'toCoupon_GEQ15min']

fig, axes = plt.subplots(nrows=1, ncols=len(cols), figsize=(16, 4))
for i, col in enumerate(cols):
    sns.boxplot(y=data[col], ax=axes[i])
    axes[i].set_title(f'Original {col}')
plt.tight_layout()
plt.show()

# %%
cols = ['toCoupon_GEQ25min' ,'direction_same' , 'direction_opp']

fig, axes = plt.subplots(nrows=1, ncols=len(cols), figsize=(16, 4))
for i, col in enumerate(cols):
    sns.boxplot(y=data[col], ax=axes[i])
    axes[i].set_title(f'Original {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Histograms

# %%
cols = ['temperature', 'has_children', 'toCoupon_GEQ5min', 'toCoupon_GEQ15min']

fig, axes = plt.subplots(nrows=1, ncols=len(cols), figsize=(16, 4))
for i, col in enumerate(cols):
    sns.histplot(data[col], ax=axes[i])  # Use sns.histplot for histograms
    axes[i].set_title(f'{col}')
plt.tight_layout()
plt.show()

# %%
cols = ['toCoupon_GEQ25min' ,'direction_same' , 'direction_opp']

fig, axes = plt.subplots(nrows=1, ncols=len(cols), figsize=(16, 4))
for i, col in enumerate(cols):
    sns.histplot(data[col], ax=axes[i]) 
    axes[i].set_title(f'{col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### > All the Numeric Columns except 'temperature' contains binary or single unique values and they dont need removal or transformation of outliers
#
# ### > For the Column 'temperature' the values are not that scattered and removing may cause loss of valuable data instead it capping or scaling will be better options also as here the extremes arent too high or too low i would prefer transforming or scaling the data in column 'temperature'.

# %% [markdown]
# # Transforming

# %%
Q1 = data['temperature'].quantile(0.25)
Q3 = data['temperature'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR  
upper_bound = Q3 + 1.5 * IQR

data['temperature'] = (data['temperature'] - lower_bound) / (upper_bound - lower_bound)

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny        0.375   2PM
# 1  No Urgent Place  Friend(s)   Sunny        0.625  10AM
# 2  No Urgent Place  Friend(s)   Sunny        0.625  10AM
# 3  No Urgent Place  Friend(s)   Sunny        0.625   2PM
# 4  No Urgent Place  Friend(s)   Sunny        0.625   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       1~3                  4~8              1~3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12610 entries, 0 to 12609
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12610 non-null  object
#  1   passanger             12610 non-null  object
#  2   weather               12610 non-null  object
#  3   temperature           12610 non-null  float64
#  4   time                  12610 non-null  object
#  5   coupon                12610 non-null  object
#  6   expiration            12610 non-null  object
#  7   gender                12610 non-null  object
#  8   age                   12610 non-null  object
#  9   maritalStatus         12610 non-null  object
#  10  has_children          12610 non-null  int64
#  11  education             12610 non-null  object
#  12  occupation            12610 non-null  object
#  13  income                12610 non-null  object
#  14  Bar                   12610 non-null  object
# ...

# %%
data.to_csv('more-cleaned-in-vehicle-coupon-recommendation.csv', index=False)
